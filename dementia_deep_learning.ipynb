# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSchilling618/project-4/blob/main/dementia_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning test 1: running model with all columns

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the dementia_get_dummies.csv.
import pandas as pd
dementia_df = pd.read_csv("dementia_OHC_v1.csv")
dementia_df.head()
# Out:
#    diabetic  alcohollevel  heartrate  bloodoxygenlevel  bodytemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       weight  mri_delay  age  cognitive_test_scores  dementia  ...  \
# 0  57.563978  36.421028   60                     10         0  ...
# 1  56.832335  31.157633   61                      1         1  ...
# 2  59.759066  37.640435   69                      8         0  ...
# 3  58.266471  50.673992   78                      5         1  ...
# 4  67.705027  27.810601   77                      0         1  ...
#
#    medication_history_Yes  nutrition_diet_Balanced Diet  \
# 0                     0.0                           0.0
# ...

# %%
print(dementia_df.nunique())
# Out:
# diabetic                                      2
# alcohollevel                               1000
# heartrate                                    41
# bloodoxygenlevel                           1000
# bodytemperature                            1000
# weight                                     1000
# mri_delay                                  1000
# age                                          31
# cognitive_test_scores                        11
# dementia                                      2
# education_level_Diploma/Degree                2
# education_level_No School                     2
# education_level_Primary School                2
# education_level_Secondary School              2
# dominant_hand_Left                            2
# dominant_hand_Right                           2
# gender_Female                                 2
# gender_Male                                   2
# family_history_No                             2
# family_history_Yes                            2
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dementia_df["dementia"].values
X = dementia_df.drop(columns="dementia").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 246
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 271 (1.06 KB)
# Trainable params: 271 (1.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 2s 3ms/step - loss: 0.7833 - accuracy: 0.4893
# Epoch 2/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7150 - accuracy: 0.5507
# Epoch 3/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6614 - accuracy: 0.6147
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6189 - accuracy: 0.6467
# Epoch 5/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5818 - accuracy: 0.7040
# Epoch 6/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5496 - accuracy: 0.7333
# Epoch 7/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5205 - accuracy: 0.7587
# Epoch 8/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4942 - accuracy: 0.7933
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4681 - accuracy: 0.8107
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0403 - accuracy: 0.9880 - 203ms/epoch - 25ms/step
# Loss: 0.040320366621017456, Accuracy: 0.9879999756813049

# %% [markdown]
# # Deep Learning test 2: running model with four key columns

# %%
## run test with four key columns
dementia_df_key_columns = dementia_df[['cognitive_test_scores', 'depression_status_Yes', 'apoe_4_Positive', 'dementia']]
dementia_df_key_columns.head()
# Out:
#    cognitive_test_scores  depression_status_Yes  apoe_4_Positive  dementia
# 0                     10                    0.0              0.0         0
# 1                      1                    0.0              1.0         1
# 2                      8                    0.0              0.0         0
# 3                      5                    1.0              0.0         1
# 4                      0                    0.0              1.0         1

# %%
# Split our preprocessed data into our features and target arrays
y = dementia_df_key_columns["dementia"].values
X = dementia_df_key_columns.drop(columns="dementia").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 6)                 24
#
#  dense_4 (Dense)             (None, 3)                 21
#
#  dense_5 (Dense)             (None, 1)                 4
#
# ...
# Total params: 49 (196.00 Byte)
# Trainable params: 49 (196.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.6914 - accuracy: 0.5227
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.5573
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6138 - accuracy: 0.5840
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5816 - accuracy: 0.6347
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.6880
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5221 - accuracy: 0.7373
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4958 - accuracy: 0.8000
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.8587
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.8667
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0713 - accuracy: 1.0000 - 179ms/epoch - 22ms/step
# Loss: 0.07128085196018219, Accuracy: 1.0

# %% [markdown]
# # Deep Learning test 3: running model without cognitive_test_scores (most important column)

# %%
## run test again with second .csv file that eliminates the cognitive_test_scores columns
drop_columns = ["cognitive_test_scores"]
dementia_df = dementia_df.drop(columns = drop_columns)

dementia_df.head()
# Out:
#    diabetic  alcohollevel  heartrate  bloodoxygenlevel  bodytemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       weight  mri_delay  age  dementia  education_level_Diploma/Degree  ...  \
# 0  57.563978  36.421028   60         0                             0.0  ...
# 1  56.832335  31.157633   61         1                             0.0  ...
# 2  59.759066  37.640435   69         0                             0.0  ...
# 3  58.266471  50.673992   78         1                             0.0  ...
# 4  67.705027  27.810601   77         1                             0.0  ...
#
#    medication_history_Yes  nutrition_diet_Balanced Diet  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dementia_df["dementia"].values
X = dementia_df.drop(columns="dementia").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 6)                 240
#
#  dense_7 (Dense)             (None, 3)                 21
#
#  dense_8 (Dense)             (None, 1)                 4
#
# ...
# Total params: 265 (1.04 KB)
# Trainable params: 265 (1.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.6994 - accuracy: 0.5267
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6705 - accuracy: 0.5760
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6487 - accuracy: 0.6133
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.6307
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6093 - accuracy: 0.6667
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5887 - accuracy: 0.6973
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.7173
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7307
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.7480
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.5006 - accuracy: 0.7640 - 298ms/epoch - 37ms/step
# Loss: 0.5005788207054138, Accuracy: 0.7639999985694885

# %% [markdown]
# # Deep Learning test 4: running model without 4 most important columns

# %%
drop_columns = ['depression_status_Yes', 'apoe_4_Positive']
dementia_df = dementia_df.drop(columns = drop_columns)

dementia_df.head()
# Out:
#    diabetic  alcohollevel  heartrate  bloodoxygenlevel  bodytemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       weight  mri_delay  age  dementia  education_level_Diploma/Degree  ...  \
# 0  57.563978  36.421028   60         0                             0.0  ...
# 1  56.832335  31.157633   61         1                             0.0  ...
# 2  59.759066  37.640435   69         0                             0.0  ...
# 3  58.266471  50.673992   78         1                             0.0  ...
# 4  67.705027  27.810601   77         1                             0.0  ...
#
#    medication_history_Yes  nutrition_diet_Balanced Diet  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dementia_df["dementia"].values
X = dementia_df.drop(columns="dementia").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 6)                 228
#
#  dense_10 (Dense)            (None, 3)                 21
#
#  dense_11 (Dense)            (None, 1)                 4
#
# ...
# Total params: 253 (1012.00 Byte)
# Trainable params: 253 (1012.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.7046 - accuracy: 0.5147
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5360
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6730 - accuracy: 0.5547
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6596 - accuracy: 0.5800
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.5987
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6332 - accuracy: 0.6253
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 0.6347
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6071 - accuracy: 0.6533
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5926 - accuracy: 0.6773
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.4735 - accuracy: 0.7440 - 187ms/epoch - 23ms/step
# Loss: 0.47352465987205505, Accuracy: 0.7440000176429749

# %%
dementia_df.columns
# Out:
# Index(['diabetic', 'alcohollevel', 'heartrate', 'bloodoxygenlevel',
#        'bodytemperature', 'weight', 'mri_delay', 'age', 'dementia',
#        'education_level_Diploma/Degree', 'education_level_No School',
#        'education_level_Primary School', 'education_level_Secondary School',
#        'dominant_hand_Left', 'dominant_hand_Right', 'gender_Female',
#        'gender_Male', 'family_history_No', 'family_history_Yes',
#        'smoking_status_Current Smoker', 'smoking_status_Former Smoker',
#        'smoking_status_Never Smoked', 'apoe_4_Negative',
#        'physical_activity_Mild Activity',
#        'physical_activity_Moderate Activity', 'physical_activity_Sedentary',
#        'depression_status_No', 'medication_history_No',
#        'medication_history_Yes', 'nutrition_diet_Balanced Diet',
#        'nutrition_diet_Low-Carb Diet', 'nutrition_diet_Mediterranean Diet',
#        'sleep_quality_Good', 'sleep_quality_Poor',
#        'chronic_health_conditions_Diabetes',
# ...
